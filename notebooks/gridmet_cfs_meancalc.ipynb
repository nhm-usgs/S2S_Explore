# %%
import xarray as xr
import glob

# %%
paths = glob.glob("*.nc")
print(paths)
# Out:
# ['cfsv2_metdata_forecast_vs_daily_18_4_0.nc', 'cfsv2_metdata_forecast_vs_daily_18_4_1.nc', 'cfsv2_metdata_forecast_vs_daily_18_4_2.nc', 'test.nc']

# %%
# paths = [
#     'http://thredds.northwestknowledge.net:8080/thredds/dodsC/NWCSC_INTEGRATED_SCENARIOS_ALL_CLIMATE/cfsv2_metdata_90day/cfsv2_metdata_forecast_vs_daily_18_4_2.nc',
#     'http://thredds.northwestknowledge.net:8080/thredds/dodsC/NWCSC_INTEGRATED_SCENARIOS_ALL_CLIMATE/cfsv2_metdata_90day/cfsv2_metdata_forecast_vs_daily_18_4_1.nc',
#     'http://thredds.northwestknowledge.net:8080/thredds/dodsC/NWCSC_INTEGRATED_SCENARIOS_ALL_CLIMATE/cfsv2_metdata_90day/cfsv2_metdata_forecast_vs_daily_18_4_0.nc'
# ]
paths = [
    'cfsv2_metdata_forecast_vs_daily_18_4_2.nc',
    'cfsv2_metdata_forecast_vs_daily_18_4_1.nc',
    'cfsv2_metdata_forecast_vs_daily_18_4_0.nc'
]
data = xr.open_mfdataset(paths,combine='nested', concat_dim='time')
# Out:
# C:\Users\rmcd\anaconda3\envs\bmi-CFS-DS\lib\site-packages\xarray\conventions.py:487: SerializationWarning: variable 'wind_speed' has _Unsigned attribute but is not of integer type. Ignoring attribute.
#   new_vars[k] = decode_cf_variable(
# C:\Users\rmcd\anaconda3\envs\bmi-CFS-DS\lib\site-packages\xarray\conventions.py:487: SerializationWarning: variable 'wind_speed' has _Unsigned attribute but is not of integer type. Ignoring attribute.
#   new_vars[k] = decode_cf_variable(
# C:\Users\rmcd\anaconda3\envs\bmi-CFS-DS\lib\site-packages\xarray\conventions.py:487: SerializationWarning: variable 'wind_speed' has _Unsigned attribute but is not of integer type. Ignoring attribute.
#   new_vars[k] = decode_cf_variable(

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:     (crs: 1, day: 32, lat: 585, lon: 1386, time: 3)
# Coordinates:
#   * crs         (crs) uint16 3
#   * day         (day) datetime64[ns] 2020-09-24 2020-09-25 ... 2020-10-25
#   * lat         (lat) float64 49.4 49.36 49.32 49.28 ... 25.19 25.15 25.11 25.07
#   * lon         (lon) float64 -124.8 -124.7 -124.7 ... -67.14 -67.1 -67.06
# Dimensions without coordinates: time
# Data variables:
#     wind_speed  (time, day, lat, lon) float32 dask.array<chunksize=(1, 32, 585, 1386), meta=np.ndarray>
# Attributes:
#     geospatial_bounds_crs:      EPSG:4326
#     Conventions:                CF-1.6
#     geospatial_bounds:          POLYGON((-124.7666666333333 49.40000000000000...
#     geospatial_lat_min:         25.066666666666666
#     geospatial_lat_max:         49.40000000000000
#     geospatial_lon_min:         -124.7666666333333
#     geospatial_lon_max:         -67.058333300000015
#     geospatial_lon_resolution:  0.041666666666666
# ...

# %%
import numpy as np
mean_ws = np.mean(data.wind_speed, axis=0)

# %%
mean_ws
# Out:
# <xarray.DataArray 'wind_speed' (day: 32, lat: 585, lon: 1386)>
# dask.array<mean_agg-aggregate, shape=(32, 585, 1386), dtype=float32, chunksize=(32, 585, 1386), chunktype=numpy.ndarray>
# Coordinates:
#   * day      (day) datetime64[ns] 2020-09-24 2020-09-25 ... 2020-10-25
#   * lat      (lat) float64 49.4 49.36 49.32 49.28 ... 25.19 25.15 25.11 25.07
#   * lon      (lon) float64 -124.8 -124.7 -124.7 -124.6 ... -67.14 -67.1 -67.06

# %%
print(data.wind_speed[:,4,200,200].values)
print(mean_ws[4,200,200].values)
# Out:
# [3.1000001 3.        4.1      ]
# 3.4000003
# C:\Users\rmcd\anaconda3\envs\bmi-CFS-DS\lib\site-packages\dask\array\numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
